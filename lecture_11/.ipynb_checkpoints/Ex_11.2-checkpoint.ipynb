# %% [markdown]
# ### Polinomial fit
#
# $$
# f(x)=3x^3-2x^2-3x+4
# $$
#
# Proviamo a fittare un polinomio di ordine 3 per $x \in [-1,1]$.

# %%
# f(x) = ax^3 + bx^2 + cx + d
a = 3
b = -2
c = -3
d = 4

def f(x):
        return a*x**3 + b*x**2 + c*x + d

# %% [markdown]
# Parametri generici:

# %%
n_train = 1000
sigma = 0.4 # noise standard deviation
n_epochs = 30

# %% [markdown]
# Generiamo i punti nel piano cartesiano che costituiranno il **training set** e il **validation set**.

# %%
import numpy as np

n_valid = int(n_train/10)   # tipically the majority of the data is partitioned into the training set.

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, n_train)
x_valid = np.random.uniform(-1, 1, n_valid)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

y_train = np.random.normal(f(x_train), sigma) 
y_valid = np.random.normal(f(x_valid), sigma)

# %% [markdown]
# Grafici del training set e del validation set rispetto al polinomio che stiamo considerando.

# %%
import matplotlib.pyplot as plt

f, axarr = plt.subplots(1,2)

axarr[0].plot(x_valid, y_target)
axarr[0].scatter(x_train, y_train, color='r')
axarr[0].grid(True); 
axarr[0].set_title('Training set')

axarr[1].plot(x_valid, y_target)
axarr[1].scatter(x_valid, y_valid, color='r')
axarr[1].grid(True); 
axarr[1].set_title('Validation set')

plt.show()

# %% [markdown]
# Gli optimizers più utilizzati sono:

# %%
sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
adag = keras.optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0)
adad = keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0)

# %% [markdown]
# ### Tentativo 1
# Partiamo dal caso più semplice: costruiamo una rete con un hidden layer composto da 2 neuroni senza attivazione.

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model_1 = tf.keras.Sequential()
model_1.add(Dense(2, input_shape=(1,)))
model_1.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model_1.compile(optimizer=sgd, loss='mse', metrics=['mse'])

# %%
model_1.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training della rete:

# %%
history = model_1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=n_epochs,
          shuffle=True, 
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/30
# 1000/1000 [==============================] - 0s 128us/sample - loss: 2.1840 - mean_squared_error: 2.1840 - val_loss: 1.0873 - val_mean_squared_error: 1.0873
# Epoch 2/30
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.7784 - mean_squared_error: 0.7784 - val_loss: 1.0209 - val_mean_squared_error: 1.0209
# Epoch 3/30
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.7641 - mean_squared_error: 0.7641 - val_loss: 0.9779 - val_mean_squared_error: 0.9779
# Epoch 4/30
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.7628 - mean_squared_error: 0.7628 - val_loss: 0.9138 - val_mean_squared_error: 0.9138
# Epoch 5/30
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.7657 - mean_squared_error: 0.7657 - val_loss: 0.9056 - val_mean_squared_error: 0.9056
# Epoch 6/30
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.7596 - mean_squared_error: 0.7596 - val_loss: 0.9670 - val_mean_squared_error: 0.9670
# Epoch 7/30
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.7579 - mean_squared_error: 0.7579 - val_loss: 1.0838 - val_mean_squared_error: 1.0838
# Epoch 8/30
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.7811 - mean_squared_error: 0.7811 - val_loss: 0.9633 - val_mean_squared_error: 0.9633
# Epoch 9/30
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.7620 - mean_squared_error: 0.7620 - val_loss: 1.0285 - val_mean_squared_error: 1.0285
# Epoch 10/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7527 - mean_squared_error: 0.7527 - val_loss: 0.9367 - val_mean_squared_error: 0.9367
# Epoch 11/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7613 - mean_squared_error: 0.7613 - val_loss: 0.9227 - val_mean_squared_error: 0.9227
# Epoch 12/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7595 - mean_squared_error: 0.7595 - val_loss: 0.9387 - val_mean_squared_error: 0.9387
# Epoch 13/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7634 - mean_squared_error: 0.7634 - val_loss: 0.9851 - val_mean_squared_error: 0.9851
# Epoch 14/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7596 - mean_squared_error: 0.7596 - val_loss: 0.9654 - val_mean_squared_error: 0.9654
# Epoch 15/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7636 - mean_squared_error: 0.7636 - val_loss: 0.8890 - val_mean_squared_error: 0.8890
# Epoch 16/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7632 - mean_squared_error: 0.7632 - val_loss: 0.9703 - val_mean_squared_error: 0.9703
# Epoch 17/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7585 - mean_squared_error: 0.7585 - val_loss: 0.9347 - val_mean_squared_error: 0.9347
# Epoch 18/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7622 - mean_squared_error: 0.7622 - val_loss: 1.0713 - val_mean_squared_error: 1.0713
# Epoch 19/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7658 - mean_squared_error: 0.7658 - val_loss: 0.9363 - val_mean_squared_error: 0.9363
# Epoch 20/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7558 - mean_squared_error: 0.7558 - val_loss: 1.0611 - val_mean_squared_error: 1.0611
# Epoch 21/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7675 - mean_squared_error: 0.7675 - val_loss: 1.0186 - val_mean_squared_error: 1.0186
# Epoch 22/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7566 - mean_squared_error: 0.7566 - val_loss: 0.9956 - val_mean_squared_error: 0.9956
# Epoch 23/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7603 - mean_squared_error: 0.7603 - val_loss: 0.9413 - val_mean_squared_error: 0.9413
# Epoch 24/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7554 - mean_squared_error: 0.7554 - val_loss: 0.9231 - val_mean_squared_error: 0.9231
# Epoch 25/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7574 - mean_squared_error: 0.7574 - val_loss: 0.9396 - val_mean_squared_error: 0.9396
# Epoch 26/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7622 - mean_squared_error: 0.7622 - val_loss: 0.9143 - val_mean_squared_error: 0.9143
# Epoch 27/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7722 - mean_squared_error: 0.7722 - val_loss: 0.8964 - val_mean_squared_error: 0.8964
# Epoch 28/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7560 - mean_squared_error: 0.7560 - val_loss: 0.9523 - val_mean_squared_error: 0.9523
# Epoch 29/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7545 - mean_squared_error: 0.7545 - val_loss: 0.9285 - val_mean_squared_error: 0.9285
# Epoch 30/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7533 - mean_squared_error: 0.7533 - val_loss: 1.0445 - val_mean_squared_error: 1.0445

# %%
model_1.get_weights()
# Out:
# [array([[-0.96451074,  0.9860486 ]], dtype=float32),
#  array([-0.2941015, -1.3056161], dtype=float32),
#  array([[ 0.26948985],
#         [-0.9846061 ]], dtype=float32),
#  array([2.3382366], dtype=float32)]

# %%
# evaluate model
score = model_1.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 100/100 [==============================] - 0s 63us/sample - loss: 1.0445 - mean_squared_error: 1.0445
#
# Test loss: 1.044520251750946
# Test accuracy: 1.0445204

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# Questa rete è troppo semplice e non è in grado di fittare il polinomio di grado 3. Proviamo ad aggiungere neuroni e una funzione di attivazione.

# %% [markdown]
# ### Tentativo 2
# Aumentiamo il numero di neuroni mantenendo un solo hidden layer. Utilizziamo una funzione di attivazione tipica: ReLu.

# %%
model_2 = tf.keras.Sequential()
model_2.add(Dense(8, input_shape=(1,)))
model_2.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model_2.compile(optimizer=sgd, loss='mse', metrics=['mse'])

history = model_2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=n_epochs,
          shuffle=True, 
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/30
# 1000/1000 [==============================] - 0s 135us/sample - loss: 2.1745 - mean_squared_error: 2.1745 - val_loss: 0.9217 - val_mean_squared_error: 0.9217
# Epoch 2/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7612 - mean_squared_error: 0.7612 - val_loss: 1.0205 - val_mean_squared_error: 1.0205
# Epoch 3/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7614 - mean_squared_error: 0.7614 - val_loss: 0.9154 - val_mean_squared_error: 0.9154
# Epoch 4/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7757 - mean_squared_error: 0.7757 - val_loss: 0.9438 - val_mean_squared_error: 0.9438
# Epoch 5/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7586 - mean_squared_error: 0.7586 - val_loss: 1.0608 - val_mean_squared_error: 1.0608
# Epoch 6/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7632 - mean_squared_error: 0.7632 - val_loss: 0.9863 - val_mean_squared_error: 0.9863
# Epoch 7/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7605 - mean_squared_error: 0.7605 - val_loss: 0.9449 - val_mean_squared_error: 0.9449
# Epoch 8/30
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.7540 - mean_squared_error: 0.7540 - val_loss: 0.9027 - val_mean_squared_error: 0.9027
# Epoch 9/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7720 - mean_squared_error: 0.7720 - val_loss: 0.9535 - val_mean_squared_error: 0.9535
# Epoch 10/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7613 - mean_squared_error: 0.7613 - val_loss: 1.0031 - val_mean_squared_error: 1.0031
# Epoch 11/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7685 - mean_squared_error: 0.7685 - val_loss: 1.0931 - val_mean_squared_error: 1.0931
# Epoch 12/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7656 - mean_squared_error: 0.7656 - val_loss: 0.9200 - val_mean_squared_error: 0.9200
# Epoch 13/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7667 - mean_squared_error: 0.7667 - val_loss: 0.9411 - val_mean_squared_error: 0.9411
# Epoch 14/30
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7584 - mean_squared_error: 0.7584 - val_loss: 0.9715 - val_mean_squared_error: 0.9715
# Epoch 15/30
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7632 - mean_squared_error: 0.7632 - val_loss: 0.9180 - val_mean_squared_error: 0.9180
# Epoch 16/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7641 - mean_squared_error: 0.7641 - val_loss: 0.9979 - val_mean_squared_error: 0.9979
# Epoch 17/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7756 - mean_squared_error: 0.7756 - val_loss: 0.9445 - val_mean_squared_error: 0.9445
# Epoch 18/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7645 - mean_squared_error: 0.7645 - val_loss: 0.9399 - val_mean_squared_error: 0.9399
# Epoch 19/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7760 - mean_squared_error: 0.7760 - val_loss: 0.9909 - val_mean_squared_error: 0.9909
# Epoch 20/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7713 - mean_squared_error: 0.7713 - val_loss: 1.0013 - val_mean_squared_error: 1.0013
# Epoch 21/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7672 - mean_squared_error: 0.7672 - val_loss: 0.8823 - val_mean_squared_error: 0.8823
# Epoch 22/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7681 - mean_squared_error: 0.7681 - val_loss: 1.0261 - val_mean_squared_error: 1.0261
# Epoch 23/30
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7538 - mean_squared_error: 0.7538 - val_loss: 0.8843 - val_mean_squared_error: 0.8843
# Epoch 24/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7676 - mean_squared_error: 0.7676 - val_loss: 0.9969 - val_mean_squared_error: 0.9969
# Epoch 25/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7609 - mean_squared_error: 0.7609 - val_loss: 0.9853 - val_mean_squared_error: 0.9853
# Epoch 26/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7621 - mean_squared_error: 0.7621 - val_loss: 0.9342 - val_mean_squared_error: 0.9342
# Epoch 27/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7611 - mean_squared_error: 0.7611 - val_loss: 0.9135 - val_mean_squared_error: 0.9135
# Epoch 28/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7544 - mean_squared_error: 0.7544 - val_loss: 0.9783 - val_mean_squared_error: 0.9783
# Epoch 29/30
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7651 - mean_squared_error: 0.7651 - val_loss: 0.9252 - val_mean_squared_error: 0.9252
# Epoch 30/30
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.7670 - mean_squared_error: 0.7670 - val_loss: 0.9233 - val_mean_squared_error: 0.9233

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model_2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Tentativo 3
# Un solo layer permette la descrizione di funzioni lineari. Consideriamo una rete con **3 hidden layer** per descrivere un polinomio di grado 3.

# %%
model_3 = tf.keras.Sequential()
model_3.add(Dense(8, input_shape=(1,)))
model_3.add(Dense(8, activation='relu'))
model_3.add(Dense(8, activation='relu'))
model_3.add(Dense(1; activation='relu'))

# compile the model choosing optimizer, loss and metrics objects
model_3.compile(optimizer=sgd, loss='mse', metrics=['mse'])

history = model_3.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=n_epochs,
          shuffle=True, 
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/30
# 1000/1000 [==============================] - 0s 164us/sample - loss: 1.6206 - mean_squared_error: 1.6206 - val_loss: 0.8734 - val_mean_squared_error: 0.8734
# Epoch 2/30
# 1000/1000 [==============================] - 0s 43us/sample - loss: 0.7989 - mean_squared_error: 0.7989 - val_loss: 0.9582 - val_mean_squared_error: 0.9582
# Epoch 3/30
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.7699 - mean_squared_error: 0.7699 - val_loss: 0.8710 - val_mean_squared_error: 0.8710
# Epoch 4/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7804 - mean_squared_error: 0.7804 - val_loss: 0.9258 - val_mean_squared_error: 0.9258
# Epoch 5/30
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.7630 - mean_squared_error: 0.7630 - val_loss: 1.0452 - val_mean_squared_error: 1.0452
# Epoch 6/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7814 - mean_squared_error: 0.7814 - val_loss: 0.8953 - val_mean_squared_error: 0.8953
# Epoch 7/30
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.7703 - mean_squared_error: 0.7703 - val_loss: 0.9844 - val_mean_squared_error: 0.9844
# Epoch 8/30
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.7695 - mean_squared_error: 0.7695 - val_loss: 0.9949 - val_mean_squared_error: 0.9949
# Epoch 9/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7720 - mean_squared_error: 0.7720 - val_loss: 1.1228 - val_mean_squared_error: 1.1228
# Epoch 10/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7643 - mean_squared_error: 0.7643 - val_loss: 0.9251 - val_mean_squared_error: 0.9251
# Epoch 11/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7741 - mean_squared_error: 0.7741 - val_loss: 0.8654 - val_mean_squared_error: 0.8654
# Epoch 12/30
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7669 - mean_squared_error: 0.7669 - val_loss: 0.8559 - val_mean_squared_error: 0.8559
# Epoch 13/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7738 - mean_squared_error: 0.7738 - val_loss: 0.9235 - val_mean_squared_error: 0.9235
# Epoch 14/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7659 - mean_squared_error: 0.7659 - val_loss: 0.9048 - val_mean_squared_error: 0.9048
# Epoch 15/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7691 - mean_squared_error: 0.7691 - val_loss: 0.9234 - val_mean_squared_error: 0.9234
# Epoch 16/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7657 - mean_squared_error: 0.7657 - val_loss: 0.8603 - val_mean_squared_error: 0.8603
# Epoch 17/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7660 - mean_squared_error: 0.7660 - val_loss: 1.3161 - val_mean_squared_error: 1.3161
# Epoch 18/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7875 - mean_squared_error: 0.7875 - val_loss: 1.0256 - val_mean_squared_error: 1.0256
# Epoch 19/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7688 - mean_squared_error: 0.7688 - val_loss: 1.2058 - val_mean_squared_error: 1.2058
# Epoch 20/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7796 - mean_squared_error: 0.7796 - val_loss: 0.9238 - val_mean_squared_error: 0.9238
# Epoch 21/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7785 - mean_squared_error: 0.7785 - val_loss: 0.8989 - val_mean_squared_error: 0.8989
# Epoch 22/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7684 - mean_squared_error: 0.7684 - val_loss: 0.9353 - val_mean_squared_error: 0.9353
# Epoch 23/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7668 - mean_squared_error: 0.7668 - val_loss: 1.0278 - val_mean_squared_error: 1.0278
# Epoch 24/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7723 - mean_squared_error: 0.7723 - val_loss: 0.8903 - val_mean_squared_error: 0.8903
# Epoch 25/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7696 - mean_squared_error: 0.7696 - val_loss: 0.9096 - val_mean_squared_error: 0.9096
# Epoch 26/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7610 - mean_squared_error: 0.7610 - val_loss: 1.0382 - val_mean_squared_error: 1.0382
# Epoch 27/30
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.7739 - mean_squared_error: 0.7739 - val_loss: 0.9179 - val_mean_squared_error: 0.9179
# Epoch 28/30
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.7662 - mean_squared_error: 0.7662 - val_loss: 0.9075 - val_mean_squared_error: 0.9075
# Epoch 29/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7638 - mean_squared_error: 0.7638 - val_loss: 0.9088 - val_mean_squared_error: 0.9088
# Epoch 30/30
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7765 - mean_squared_error: 0.7765 - val_loss: 0.8995 - val_mean_squared_error: 0.8995

# %%
x_predicted_3 = np.random.uniform(-1, 1, 100)
y_predicted_3 = model_3.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
